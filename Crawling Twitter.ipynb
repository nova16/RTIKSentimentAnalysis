# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/MATERI/Materi Pembicata/RTIK/Data'
# Out:
# /content/drive/MyDrive/MATERI/Materi Pembicata/RTIK/Data

# %%
#import the libraries
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd 
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
# API key untuk Crawling Twitter 
# API key bisa didapatkan di website twitter developer
consumer_key= # API key bisa didapatkan di website twitter developer
consumer_secret= # API key bisa didapatkan di website twitter developer
access_token= # API key bisa didapatkan di website twitter developer
access_token_secret= 'JcoMQLJ71PI4rd1H6Bd4mRuKQOi0aH4U2aKfYgxYdlXwz'

# %%
# proses autentikasi.
authenticate = tweepy.OAuthHandler(consumer_key, consumer_secret)
authenticate.set_access_token (access_token, access_token_secret)
api = tweepy.API(authenticate, wait_on_rate_limit = True)

# %%
# crawling 100 data tweet dari twitter dengan keyword indihome dari tanggal 1 Jan 2022
posts = api.search(q="mudik2022", count = 100, tweet_mode = "extended", since="2022-04-25")

# %%
# tampilkan 5 data teratas
print("show the 5 recent tweets : \n")
i = 1
for tweet in posts[0:5] :
  print(str(i) + ') '+ tweet.full_text.lower() + '\n')
  i = i+1
# Out:
# show the 5 recent tweets :
#
# 1) prediksi masyarakat yang akan mudik pada lebaran tahun ini.
# .
# #kuatbaca #kuatbacacom #media #medsos #info #informasi #mudik #mudik2022 #mudikgratis #infomudik #prediksimudik #prediksi #pemerintah #pulangkampung #lebaran #lebaran2022 #idulfitri #pesawat #keretaapi #kapallaut #bus https://t.co/gjtfgemlpt
#
# 2) all new honda hr-v hadir dengan fitur honda sensing di semua tipenya.
#
# #khilafclub #honda #hrv #ramadhan #mudik2022 #booster #mobilbaru https://t.co/nrk5zuc8vp
#
# 3) senin, 25 april 2022 pukul 14.20 wib, pemberian arahan kepada juru pakir di kota cirebon agar tidak menempatkan parkir sembarang yang akan menimbulkan kemacetan.
#
# #mudik2022 #mudikamansehat https://t.co/dpapv5iw1q
#
# 4) infografis: 6 tips mudik aman &amp; nyaman
#
# apa saja? simak infografis dibawah 👇
#
# https://t.co/zkcacvkjmu
#
# #digdataid #mudik #mudik2022 #mudiklebaran #mudikaman #mudiknyaman #mudikasyik #infomudik #tipsmudik https://t.co/rt8ojqcdci
#
# ...

# %%
# membuat dataframe dengan kolom tweets
df = pd.DataFrame([ tweet.full_text.lower() for tweet in posts], columns = ['Tweets'])

# %%
# menampilkan 5 data teratas dari dataframe df
df.head()
# Out:
#                                               Tweets
# 0  prediksi masyarakat yang akan mudik pada lebar...
# 1  all new honda hr-v hadir dengan fitur honda se...
# 2  senin, 25 april 2022 pukul 14.20 wib, pemberia...
# 3  infografis: 6 tips mudik aman &amp; nyaman\n\n...
# 4  #mudiklebaran2022 #mudiksehatkitaaman #mudik20...

# %%
# simpan df dalam file csv
df.to_csv('mudik2022.csv', header='Tweets', index=False)
